# %% [markdown]
# <a href="https://colab.research.google.com/github/callsourav1979-personal/AILearning/blob/main/TF_20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This is *1st* **Heading**

# %%
print("Hello World")
# Out:
# Hello World

# %%
1+3
# Out:
# 4

# %%
# !cat sample_data/mnist_test.csv

# %%
import pandas as pd
pd.read_csv("TB_Burden_Country.csv").head()
# Out:
#   Country or territory name ISO 2-character country/territory code  \
# 0               Afghanistan                                     AF
# 1               Afghanistan                                     AF
# 2               Afghanistan                                     AF
# 3               Afghanistan                                     AF
# 4               Afghanistan                                     AF
#
#   ISO 3-character country/territory code  ISO numeric country/territory code  \
# 0                                    AFG                                   4
# 1                                    AFG                                   4
# 2                                    AFG                                   4
# 3                                    AFG                                   4
# 4                                    AFG                                   4
#
#   Region  Year  Estimated total population number  \
# ...
